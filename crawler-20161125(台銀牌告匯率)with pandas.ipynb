# %%
import pandas as pd
URL = "http://rate.bot.com.tw/xrt/quote/l6m/JPY"
table = pd.read_html(URL)[0]
table
# Out:
#            掛牌日期    掛牌日期.1      幣別    現金匯率  Unnamed: 4    即期匯率  Unnamed: 6  \
# 0    2016/11/25  日圓 (JPY)  0.2739  0.2849      0.2803  0.2843         NaN
# 1    2016/11/24  日圓 (JPY)  0.2735  0.2845      0.2799  0.2839         NaN
# 2    2016/11/23  日圓 (JPY)  0.2787  0.2897      0.2851  0.2891         NaN
# 3    2016/11/22  日圓 (JPY)  0.2792  0.2902      0.2856  0.2896         NaN
# 4    2016/11/21  日圓 (JPY)  0.2800  0.2910      0.2864  0.2904         NaN
# 5    2016/11/18  日圓 (JPY)  0.2806  0.2916      0.2870  0.2910         NaN
# 6    2016/11/17  日圓 (JPY)  0.2835  0.2945      0.2899  0.2939         NaN
# 7    2016/11/16  日圓 (JPY)  0.2826  0.2936      0.2890  0.2930         NaN
# 8    2016/11/15  日圓 (JPY)  0.2861  0.2971      0.2925  0.2965         NaN
# 9    2016/11/14  日圓 (JPY)  0.2886  0.2996      0.2950  0.2990         NaN
# 10   2016/11/11  日圓 (JPY)  0.2896  0.3006      0.2960  0.3000         NaN
# 11   2016/11/10  日圓 (JPY)  0.2910  0.3020      0.2974  0.3014         NaN
# ...
